# %%
import numpy as np
import pandas as pd

# %%
import os
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt

# %%
image_path = r'C:\Users\KIIT\Documents\roco_dataset_extracted\all_data\train\radiology\images'

caption=r'C:\Users\KIIT\Documents\roco_dataset_extracted\all_data\train\radiology\captions.txt'

# %%
df = pd.read_table(caption, header=None, names=['image_name', 'caption'])
print(df.head())
# Out:
#    image_name                                            caption
# 0  ROCO_00002   Computed tomography scan in axial view showin...
# 1  ROCO_00003   Bacterial contamination occurred after comple...
# 2  ROCO_00004   The patient had residual paralysis of the han...
# 3  ROCO_00005      Panoramic radiograph after immediate loading.
# 4  ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...

# %%
df.describe()
# Out:
#         image_name                         caption
# count        65450                           65450
# unique       65450                           64772
# top     ROCO_00002   Initial panoramic radiograph.
# freq             1                              19

# %%
df['caption_length']=df['caption'].str.len()

# %%
df.head()
# Out:
#    image_name                                            caption  \
# 0  ROCO_00002   Computed tomography scan in axial view showin...
# 1  ROCO_00003   Bacterial contamination occurred after comple...
# 2  ROCO_00004   The patient had residual paralysis of the han...
# 3  ROCO_00005      Panoramic radiograph after immediate loading.
# 4  ROCO_00007   Plain abdomen x-ray: Multiple air levels at t...
#
#    caption_length
# 0              88
# 1             142
# 2             320
# 3              46
# 4             124

# %%
print(df['caption_length'].describe())
# Out:
# count    65450.000000
# mean       138.963453
# std        104.237943
# min          3.000000
# 25%         73.000000
# 50%        114.000000
# 75%        175.000000
# max       2855.000000
# Name: caption_length, dtype: float64

# %%
dlink_url = r'C:\Users\KIIT\Documents\roco_dataset_extracted\all_data\train\radiology\dlinks.txt'
dlink = pd.read_table(dlink_url, header=None, names=['image_id', 'dlink', 'image'])
print(dlink)
# Out:
#          image_id                                              dlink  \
# 0      ROCO_00002  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 1      ROCO_00003  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 2      ROCO_00004  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 3      ROCO_00005  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 4      ROCO_00007  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# ...           ...                                                ...
# 65445  ROCO_81819  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 65446  ROCO_81820  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 65447  ROCO_81821  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 65448  ROCO_81822  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
# 65449  ROCO_81823  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...
#
#                                     image
# 0                     AMHSR-4-14-g002.jpg
# 1                  IJD2009-150251.001.jpg
# 2             11999_2007_30_Fig6_HTML.jpg
# 3                  IJD2013-683423.005.jpg
# 4              amjcaserep-17-301-g001.jpg
# ...                                   ...
# 65445  CRIM.HEMATOLOGY2012-490438.001.jpg
# 65446               rb-50-03-0190-g13.jpg
# 65447                 kjr-11-612-g001.jpg
# 65448                 AJNS-7-151-g002.jpg
# 65449               pone.0050319.g002.jpg
#
# [65450 rows x 3 columns]

# %%
dlink.describe()
# Out:
#           image_id                                              dlink    image
# count        65450                                              65450    65450
# unique       65450                                              37396    60990
# top     ROCO_00002  wget -r ftp://ftp.ncbi.nlm.nih.gov/pub/pmc/oa_...  gr1.jpg
# freq             1                                                 37     1444

# %%
# Define paths for each split (train, test, validation) and categories (radiology, non-radiology)
base_dir = r'C:\Users\KIIT\Documents\roco_dataset_extracted\all_data'

# Define the splits and categories
splits = ['train', 'test', 'validation']
categories = ['radiology', 'non-radiology']

# Initialize an empty list to store the data
data = []

# Loop through each split and category to read captions
for split in splits:
    for category in categories:
        # Define paths for images and captions.txt
        category_dir = os.path.join(base_dir, split, category)
        captions_file = os.path.join(category_dir, 'captions.txt')
        
        # Read the captions file if it exists
        if os.path.exists(captions_file):
            with open(captions_file, 'r', encoding='utf-8', errors='ignore') as file:
                # Read each line in the captions file
                for line in file:
                    image_id = line[:12]    # Assuming the first 12 characters are the image ID
                    caption = line[12:].strip()  # The rest of the line is the caption text
                    label = category  # Set label as 'radiology' or 'non-radiology'
                    
                    # Append to data list with image ID, caption, label, and split type
                    data.append([image_id, caption, label, split])

# Create a DataFrame with the collected data
df = pd.DataFrame(data, columns=['image_id', 'caption', 'label', 'split'])

# Display the first few rows of the DataFrame to verify
df
# Out:
#             image_id                                            caption  \
# 0      ROCO_00002\t   Computed tomography scan in axial view showing...
# 1      ROCO_00003\t   Bacterial contamination occurred after complet...
# 2      ROCO_00004\t   The patient had residual paralysis of the hand...
# 3      ROCO_00005\t       Panoramic radiograph after immediate loading.
# 4      ROCO_00007\t   Plain abdomen x-ray: Multiple air levels at th...
# ...              ...                                                ...
# 79743  ROCO_87894\t   Scanning electron photomicrograph of blood cel...
# 79744  ROCO_87904\t   SEM of Solenopsis elhawagryi sp. n. minor work...
# 79745  ROCO_87918\t   Under visualization through the anterolateral ...
# 79746  ROCO_87936\t   The endoscopic view demonstrated progressive d...
# 79747  ROCO_87952\t   A 7 Fr Kimny guiding catheter (Boston Scientif...
#
#                label       split
# 0          radiology       train
# 1          radiology       train
# 2          radiology       train
# 3          radiology       train
# 4          radiology       train
# ...              ...         ...
# 79743  non-radiology  validation
# 79744  non-radiology  validation
# 79745  non-radiology  validation
# 79746  non-radiology  validation
# 79747  non-radiology  validation
#
# [79748 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# Pie chart for train/test/validation distribution
split_counts = df['split'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(split_counts, labels=split_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon', 'lightgreen'])
plt.title("Distribution of Train, Test, and Validation Splits")
plt.show()

# Pie chart for radiology and non-radiology distribution
label_counts = df['label'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue'])
plt.title("Distribution of Radiology and Non-Radiology Labels")
plt.show()

# %% [markdown]
# ## ANALYSIS OF DATA

# %%
df['caption_length'] = df['caption'].str.len()

# %%
sns.histplot(df['caption_length'],bins=10)
# Out:
# <Axes: xlabel='caption_length', ylabel='Count'>

# %%
from wordcloud import WordCloud

# %%
all_captions = ' '.join(df['caption'])

# %%
wordcloud = WordCloud(width=800, height=400, max_words=20).generate(all_captions)

# %%
plt.imshow(wordcloud)

# %%
from collections import Counter
import re

# %%
words = re.findall(r'\w+', all_captions.lower())
# frequency of each word
word_counts = Counter(words)
# Display the most common words
print(word_counts.most_common(5))
# Out:
# [('the', 120433), ('of', 77601), ('and', 36235), ('a', 33406), ('in', 31768)]

# %%
top_words=word_counts.most_common(10)

# %%
words, counts = zip(*top_words)
plt.bar(words, counts, color='blue')
plt.title("Top 10 Most Common Words in Captions")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(20, 4))
sns.boxplot(x=df['caption_length'], color='green')
plt.title('Box Plot of Caption Lengths')
plt.xlabel('Caption Length')
plt.show()

# %%
from textblob import TextBlob
sentiment_scores = df['caption'].apply(lambda x: TextBlob(x).sentiment.polarity)
plt.hist(sentiment_scores, bins=20, color='green', edgecolor='black')
plt.xlabel("Sentiment Score")
plt.ylabel("Frequency")
plt.title("Sentiment Distribution of Captions")
plt.show()

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
import cv2

# %%
image_files=[f for f in os.listdir(image_path) if f.endswith(".jpg")]

# %%
img_path=os.path.join(image_path,image_files[21])

# %%
img_path
# Out:
# 'C:\\Users\\KIIT\\Documents\\roco_dataset_extracted\\all_data\\train\\radiology\\images\\PMC1087206_pmed.0020079.g004.jpg'

# %%
img=cv2.imread(img_path)
img
# Out:
# array([[[104, 111,  44],
#         [ 90,  96,  31],
#         [ 91,  95,  36],
#         ...,
#         [101, 108,  41],
#         [101, 106,  44],
#         [ 97, 103,  46]],
#
#        [[ 87,  93,  28],
#         [ 71,  76,  15],
#         [ 70,  73,  17],
#         ...,
#         [ 70,  72,  26],
#         [ 65,  66,  16],
#         [ 61,  63,  11]],
#
#        [[ 89,  93,  34],
#         [ 71,  74,  18],
#         [ 67,  69,  17],
#         ...,
#         [ 88,  84,  60],
#         [ 63,  61,  27],
#         [ 45,  44,   0]],
#
#        ...,
#
#        [[ 96,  99,  43],
#         [ 75,  78,  23],
#         [ 69,  70,  20],
#         ...,
#         [ 71,  71,  23],
#         [ 63,  63,  15],
#         [ 53,  53,   5]],
#
#        [[ 87,  90,  35],
#         [ 70,  72,  20],
#         [ 66,  66,  18],
#         ...,
#         [ 67,  67,  19],
#         [ 61,  61,  13],
#         [ 52,  52,   4]],
#
#        [[ 65,  68,  13],
#         [ 52,  53,   3],
#         [ 50,  50,   4],
#         ...,
#         [ 55,  55,   7],
#         [ 52,  52,   4],
#         [ 46,  46,   0]]], dtype=uint8)

# %%
image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off') 
plt.show()

# %%
image_rgb.shape
# Out:
# (485, 646, 3)

# %%
target_size=(224,224)
resizedimg=cv2.resize(image_rgb,target_size)

# %%
plt.imshow(resizedimg)
plt.axis('off')
plt.show()

# %%
resizedimg.shape
# Out:
# (224, 224, 3)

# %%
img_processed=image_rgb

# %%
img_normalized=img_processed/255

# %%
img_normalized
# Out:
# array([[[0.17254902, 0.43529412, 0.40784314],
#         [0.12156863, 0.37647059, 0.35294118],
#         [0.14117647, 0.37254902, 0.35686275],
#         ...,
#         [0.16078431, 0.42352941, 0.39607843],
#         [0.17254902, 0.41568627, 0.39607843],
#         [0.18039216, 0.40392157, 0.38039216]],
#
#        [[0.10980392, 0.36470588, 0.34117647],
#         [0.05882353, 0.29803922, 0.27843137],
#         [0.06666667, 0.28627451, 0.2745098 ],
#         ...,
#         [0.10196078, 0.28235294, 0.2745098 ],
#         [0.0627451 , 0.25882353, 0.25490196],
#         [0.04313725, 0.24705882, 0.23921569]],
#
#        [[0.13333333, 0.36470588, 0.34901961],
#         [0.07058824, 0.29019608, 0.27843137],
#         [0.06666667, 0.27058824, 0.2627451 ],
#         ...,
#         [0.23529412, 0.32941176, 0.34509804],
#         [0.10588235, 0.23921569, 0.24705882],
#         [0.        , 0.17254902, 0.17647059]],
#
#        ...,
#
#        [[0.16862745, 0.38823529, 0.37647059],
#         [0.09019608, 0.30588235, 0.29411765],
#         [0.07843137, 0.2745098 , 0.27058824],
#         ...,
#         [0.09019608, 0.27843137, 0.27843137],
#         [0.05882353, 0.24705882, 0.24705882],
#         [0.01960784, 0.20784314, 0.20784314]],
#
#        [[0.1372549 , 0.35294118, 0.34117647],
#         [0.07843137, 0.28235294, 0.2745098 ],
#         [0.07058824, 0.25882353, 0.25882353],
#         ...,
#         [0.0745098 , 0.2627451 , 0.2627451 ],
#         [0.05098039, 0.23921569, 0.23921569],
#         [0.01568627, 0.20392157, 0.20392157]],
#
#        [[0.05098039, 0.26666667, 0.25490196],
#         [0.01176471, 0.20784314, 0.20392157],
#         [0.01568627, 0.19607843, 0.19607843],
#         ...,
#         [0.02745098, 0.21568627, 0.21568627],
#         [0.01568627, 0.20392157, 0.20392157],
#         [0.        , 0.18039216, 0.18039216]]])

# %%
import tensorflow as tf

# %%
img=np.expand_dims(img,axis=0)

# %%
datagen=tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=0.2
                                        )
it=datagen.flow(img,batch_size=1)
augmented_images=[next(it)[0] for _ in range(5)]

# %%
plt.figure(figsize=(20,5))
for i,aug_img in enumerate(augmented_images):
  plt.subplot(1,5,i+1)
  plt.imshow(aug_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].

# %%
image_rgb.shape
# Out:
# (642, 600, 3)

# %% [markdown]
# #### NLP PREPROCESSING TECHNIQUES

# %%
captions = " ".join(df['caption'])
print(captions[:500])
# Out:
# Computed tomography scan in axial view showing obliteration of the left maxillary sinus Bacterial contamination occurred after completion of root canal treatment in the tooth, which remained with a temporary filling for 15 month. The patient had residual paralysis of the hand after poliomyelitis. It was necessary to stabilize the thumb with reference to the index finger. This was accomplished by placing a graft from the bone bank between the first and second metacarpals. The roentgenogram shows

# %%
captions=captions.lower()

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words=set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
text_input = " ".join([word.lower() for word in captions.split() if word.lower() not in stop_words][:500])

# %%
print(text_input)
# Out:
# computed tomography scan axial view showing obliteration left maxillary sinus bacterial contamination occurred completion root canal treatment tooth, remained temporary filling 15 month. patient residual paralysis hand poliomyelitis. necessary stabilize thumb reference index finger. accomplished placing graft bone bank first second metacarpals. roentgenogram shows complete healing graft one year later. panoramic radiograph immediate loading. plain abdomen x-ray: multiple air levels mid-abdomen (arrows), radiopaque shadow, air diaphragm. 3-year-old child visual difficulties. axial flair image show supra-sellar lesion extending temporal lobes along optic tracts (arrows) moderate mass effect, compatible optic glioma. flair hyperintensity also noted left mesencephalon additional tumoral involvement showing subtrochanteric fracture porotic bone. post orthodontic treatment. root canal therapy done maxillary incisors two sequential thrombi distal segment obtuse marginal 2 (om2). example mri image takes advantage joint effusion contrast material acute scenario. 57x46mm (150 x 150 dpi). child abduction flexion right lower extremity hyperextension tibia femur, associated dislocation left hip, probably result dangerous position adduction production pathological dislocation. roentgenogram mother’s pelvis, one week delivery, showed deformity utero. axial t2 haste mr image shows loss normal trilaminar myometrial architecture mild focal thinning placenta site compression myometrium front aorta (black arrow), proximal bifurcation. normal trilaminar signal pattern myometrium seen regions (white arrows) hydronephrosis appearance sonography. coronary angiogram demonstrating occluded om1 om2 arteries. cardiac catheterization showing normal coronaries tumor blush. follow-up coronary angiography fluoroscopy showed gap stent strut. a-d: gap stent strut. right-sided metatarsal dorsoplantar projection.cow. age group iv—cattle 4–8 years. (a) narrow symphysis (b) indistinct bone surface. fourth patient’s mri orthopantomograph focal steatosis liver parenchyma preoperative tte, end diastole (preop pics). magnetic resonance t2 weighted image showing foraminal extensions cysts post-treatment mriaxial t1-weighted, contrast-enhanced image showing lesion figure 3. abdominal ct scan showing pancreatic pseudocyst axial contrast-enhanced computed tomography image abdomen 3 months anti tuberculous treatment showing complete resolution lesions lytic lesions (arrows) involving humerus. fluoroscopy image evar procedure. ap pelvis x-ray obtained 6 weeks initial presentation shows early femoral head collapse. postoperative control following periapical surgery. ct image liver shows air hepatic veins (arrow) air-contrast level inferior vena cava (arrowhead). sfa perforated glidewire insertion attempt cross lesion. postoperative computed tomography scan 18-year-old woman venous tumor thrombus. axial t1w fat-saturated, postcontrast mr image pelvis. x-ray control calcaneus drilling transvaginal image maternal pelvis demonstrating cervical length. probe first advanced anterior fornix slightly withdrawn good image quality maintained avoiding placing pressure cervix. cervical length measured internal external os. endocervical canal also marked differentiated echolucency. anterior posterior cervical walls similar thickness. opg showing well defined corticated radiolucency containing two supernumerary premolars computed tomography scan obtained december 24, 2014 (7 days treatment).notes: scan demonstrates mass upper lobe left lung, multiple enlarged lymph nodes mediastinum, pleural effusion; arrow indicates abundant pericardial effusion around pericardium. coronal contrast chest ct image showing two aberrant arteries (white arrow) arising directly thoracic aorta left lower lobe cystic lesion. osteoid osteoma femur. axial ct scan shows nidus (arrow) within cortex, surrounding dense sclerosis (arrowhead) mandibular occlusal view radiograph showing fusion mandibular teeth talon cus ...

# %%
from textblob import TextBlob

# %%
TextBlob(text_input).correct()
# Out:
# TextBlob("computer cosmography scan animal view showing obliteration left maxillary sinus bacterial contamination occurred completion root canal treatment tooth, remained temporary filling 15 month. patient residual paralysis hand poliomyelitis. necessary stability thumb reference index finger. accomplished placing graft bone bank first second metacarpals. roentgenogram shows complete healing graft one year later. panorama radiogram immediate loading. plain abdomen x-ray: multiple air levels mid-abdomen (arrows), radiopaque shadow, air diaphragm. 3-year-old child visual difficulties. animal flair image show supra-cellar lesion extending temporal loves along optic tracts (arrows) moderate mass effect, compatible optic glioma. flair hyperintensity also noted left mesencephalon additional moral involvement showing subtrochanteric fracture poetic bone. post orthodontic treatment. root canal therapy done maxillary incisors two sequential thrombi distal segment abuse marginal 2 (om). example mr image takes advantage joint effusion contrast material acute scenario. 57x46mm (150 x 150 dip). child abduction flexion right lower extremity hyperextension tibia femur, associated dislocation left hip, probably result dangerous position adduction production pathological dislocation. roentgenogram mother’s pelvis, one week delivery, showed deformity utero. animal to haste mr image shows loss normal trilaminar myometrial architecture mild local thinning placenta site compression myometrium front aorta (black arrow), proximal bifurcation. normal trilaminar signal pattern myometrium seen regions (white arrows) hydronephrosis appearance monograph. coronary angiogram demonstrating occluded om om arteries. cardiac catheterization showing normal coronaries tumor blush. follow-up coronary angiography fluoroscopy showed gap sent strut. a-d: gap sent strut. right-sided metatarsal dorsoplantar projection.cow. age group iv—cattle 4–8 years. (a) narrow symphysis (b) indistinct bone surface. fourth patient’s mr orthopantomograph local stenosis liver parenchyma preoperative the, end diastole (prop pick). magnetic resonance to weighted image showing foraminal extensions cysts post-treatment mriaxial to-weighted, contrast-enhanced image showing lesion figure 3. abdominal it scan showing pancreatic pseudocyst animal contrast-enhanced computer cosmography image abdomen 3 months anti tuberculous treatment showing complete resolution lesions lyric lesions (arrows) involving humerus. fluoroscopy image ever procedure. a pelvis x-ray obtained 6 weeks initial presentation shows early femoral head collapse. postoperative control following periodical surgery. it image liver shows air hepatic veins (arrow) air-contrast level inferior vena cava (arrowhead). sofa perforated glidewire insertion attempt cross lesion. postoperative computer cosmography scan 18-year-old woman venous tumor thrombus. animal tow fat-saturated, postcontrast mr image pelvis. x-ray control calcaneus drilling transvaginal image maternal pelvis demonstrating cervical length. probe first advanced anterior forbid slightly withdrawn good image quality maintained avoiding placing pressure croix. cervical length measured internal external os. endocervical canal also marked differentiated echolucency. anterior posterior cervical walls similar thickness. org showing well defined corticated radiolucency containing two supernumerary premolars computer cosmography scan obtained december 24, 2014 (7 days treatment).notes: scan demonstrates mass upper love left lung, multiple enlarged lymph nodes mediastinum, pleural effusion; arrow indicates abundant pericardium effusion around pericardium. corona contrast chest it image showing two aberrant arteries (white arrow) arising directly thoracic aorta left lower love cystic lesion. osteoid osteoma femur. animal it scan shows nidus (arrow) within cortex, surrounding dense sclerosis (arrowhead) mandibular occlusal view radiogram showing fusion mandibular teeth salon cu ...

# %% [markdown]
# #### TOKENIZATION

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
sent_tokenize(text_input)
# Out:
# ['computed tomography scan axial view showing obliteration left maxillary sinus bacterial contamination occurred completion root canal treatment tooth, remained temporary filling 15 month.',
#  'patient residual paralysis hand poliomyelitis.',
#  'necessary stabilize thumb reference index finger.',
#  'accomplished placing graft bone bank first second metacarpals.',
#  'roentgenogram shows complete healing graft one year later.',
#  'panoramic radiograph immediate loading.',
#  'plain abdomen x-ray: multiple air levels mid-abdomen (arrows), radiopaque shadow, air diaphragm.',
#  '3-year-old child visual difficulties.',
#  'axial flair image show supra-sellar lesion extending temporal lobes along optic tracts (arrows) moderate mass effect, compatible optic glioma.',
#  'flair hyperintensity also noted left mesencephalon additional tumoral involvement showing subtrochanteric fracture porotic bone.',
#  'post orthodontic treatment.',
#  'root canal therapy done maxillary incisors two sequential thrombi distal segment obtuse marginal 2 (om2).',
#  'example mri image takes advantage joint effusion contrast material acute scenario.',
#  '57x46mm (150 x 150 dpi).',
#  'child abduction flexion right lower extremity hyperextension tibia femur, associated dislocation left hip, probably result dangerous position adduction production pathological dislocation.',
#  'roentgenogram mother’s pelvis, one week delivery, showed deformity utero.',
#  'axial t2 haste mr image shows loss normal trilaminar myometrial architecture mild focal thinning placenta site compression myometrium front aorta (black arrow), proximal bifurcation.',
#  'normal trilaminar signal pattern myometrium seen regions (white arrows) hydronephrosis appearance sonography.',
#  'coronary angiogram demonstrating occluded om1 om2 arteries.',
#  'cardiac catheterization showing normal coronaries tumor blush.',
#  'follow-up coronary angiography fluoroscopy showed gap stent strut.',
#  'a-d: gap stent strut.',
#  'right-sided metatarsal dorsoplantar projection.cow.',
#  'age group iv—cattle 4–8 years.',
#  '(a) narrow symphysis (b) indistinct bone surface.',
#  'fourth patient’s mri orthopantomograph focal steatosis liver parenchyma preoperative tte, end diastole (preop pics).',
#  'magnetic resonance t2 weighted image showing foraminal extensions cysts post-treatment mriaxial t1-weighted, contrast-enhanced image showing lesion figure 3. abdominal ct scan showing pancreatic pseudocyst axial contrast-enhanced computed tomography image abdomen 3 months anti tuberculous treatment showing complete resolution lesions lytic lesions (arrows) involving humerus.',
#  'fluoroscopy image evar procedure.',
#  'ap pelvis x-ray obtained 6 weeks initial presentation shows early femoral head collapse.',
#  'postoperative control following periapical surgery.',
#  'ct image liver shows air hepatic veins (arrow) air-contrast level inferior vena cava (arrowhead).',
#  'sfa perforated glidewire insertion attempt cross lesion.',
#  'postoperative computed tomography scan 18-year-old woman venous tumor thrombus.',
#  'axial t1w fat-saturated, postcontrast mr image pelvis.',
#  'x-ray control calcaneus drilling transvaginal image maternal pelvis demonstrating cervical length.',
#  'probe first advanced anterior fornix slightly withdrawn good image quality maintained avoiding placing pressure cervix.',
#  'cervical length measured internal external os.',
#  'endocervical canal also marked differentiated echolucency.',
#  'anterior posterior cervical walls similar thickness.',
#  'opg showing well defined corticated radiolucency containing two supernumerary premolars computed tomography scan obtained december 24, 2014 (7 days treatment).notes: scan demonstrates mass upper lobe left lung, multiple enlarged lymph nodes mediastinum, pleural effusion; arrow indicates abundant pericardial effusion around pericardium.',
#  'coronal contrast chest ct image showing two aberrant arteries (white arrow) arising directly thoracic aorta left lower lobe cystic lesion.',
#  'osteoid osteoma femur.',
#  'axial ct scan shows nidus (arrow) within cortex, surrounding dense sclerosis (arrowhead) mandibular occlusal view radiograph showing fusion mandibular teeth talon cusp respect 41 42 intraoperative t2w mr image showing']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(text_input)
# Out:
# ['computed',
#  'tomography',
#  'scan',
#  'axial',
#  'view',
#  'showing',
#  'obliteration',
#  'left',
#  'maxillary',
#  'sinus',
#  'bacterial',
#  'contamination',
#  'occurred',
#  'completion',
#  'root',
#  'canal',
#  'treatment',
#  'tooth',
#  ',',
#  'remained',
#  'temporary',
#  'filling',
#  '15',
#  'month',
#  '.',
#  'patient',
#  'residual',
#  'paralysis',
#  'hand',
#  'poliomyelitis',
#  '.',
#  'necessary',
#  'stabilize',
#  'thumb',
#  'reference',
#  'index',
#  'finger',
#  '.',
#  'accomplished',
#  'placing',
#  'graft',
#  'bone',
#  'bank',
#  'first',
#  'second',
#  'metacarpals',
#  '.',
#  'roentgenogram',
#  'shows',
#  'complete',
#  'healing',
#  'graft',
#  'one',
#  'year',
#  'later',
#  '.',
#  'panoramic',
#  'radiograph',
#  'immediate',
#  'loading',
#  '.',
#  'plain',
#  'abdomen',
#  'x',
#  '-',
#  'ray',
#  ':',
#  'multiple',
#  'air',
#  'levels',
#  'mid',
#  '-',
#  'abdomen',
#  '(',
#  'arrows',
#  '),',
#  'radiopaque',
#  'shadow',
#  ',',
#  'air',
#  'diaphragm',
#  '.',
#  '3',
#  '-',
#  'year',
#  '-',
#  'old',
#  'child',
#  'visual',
#  'difficulties',
#  '.',
#  'axial',
#  'flair',
#  'image',
#  'show',
#  'supra',
#  '-',
#  'sellar',
#  'lesion',
#  'extending',
#  'temporal',
#  'lobes',
#  'along',
#  'optic',
#  'tracts',
#  '(',
#  'arrows',
#  ')',
#  'moderate',
#  'mass',
#  'effect',
#  ',',
#  'compatible',
#  'optic',
#  'glioma',
#  '.',
#  'flair',
#  'hyperintensity',
#  'also',
#  'noted',
#  'left',
#  'mesencephalon',
#  'additional',
#  'tumoral',
#  'involvement',
#  'showing',
#  'subtrochanteric',
#  'fracture',
#  'porotic',
#  'bone',
#  '.',
#  'post',
#  'orthodontic',
#  'treatment',
#  '.',
#  'root',
#  'canal',
#  'therapy',
#  'done',
#  'maxillary',
#  'incisors',
#  'two',
#  'sequential',
#  'thrombi',
#  'distal',
#  'segment',
#  'obtuse',
#  'marginal',
#  '2',
#  '(',
#  'om2',
#  ').',
#  'example',
#  'mri',
#  'image',
#  'takes',
#  'advantage',
#  'joint',
#  'effusion',
#  'contrast',
#  'material',
#  'acute',
#  'scenario',
#  '.',
#  '57x46mm',
#  '(',
#  '150',
#  'x',
#  '150',
#  'dpi',
#  ').',
#  'child',
#  'abduction',
#  'flexion',
#  'right',
#  'lower',
#  'extremity',
#  'hyperextension',
#  'tibia',
#  'femur',
#  ',',
#  'associated',
#  'dislocation',
#  'left',
#  'hip',
#  ',',
#  'probably',
#  'result',
#  'dangerous',
#  'position',
#  'adduction',
#  'production',
#  'pathological',
#  'dislocation',
#  '.',
#  'roentgenogram',
#  'mother',
#  '’',
#  's',
#  'pelvis',
#  ',',
#  'one',
#  'week',
#  'delivery',
#  ',',
#  'showed',
#  'deformity',
#  'utero',
#  '.',
#  'axial',
#  't2',
#  'haste',
#  'mr',
#  'image',
#  'shows',
#  'loss',
#  'normal',
#  'trilaminar',
#  'myometrial',
#  'architecture',
#  'mild',
#  'focal',
#  'thinning',
#  'placenta',
#  'site',
#  'compression',
#  'myometrium',
#  'front',
#  'aorta',
#  '(',
#  'black',
#  'arrow',
#  '),',
#  'proximal',
#  'bifurcation',
#  '.',
#  'normal',
#  'trilaminar',
#  'signal',
#  'pattern',
#  'myometrium',
#  'seen',
#  'regions',
#  '(',
#  'white',
#  'arrows',
#  ')',
#  'hydronephrosis',
#  'appearance',
#  'sonography',
#  '.',
#  'coronary',
#  'angiogram',
#  'demonstrating',
#  'occluded',
#  'om1',
#  'om2',
#  'arteries',
#  '.',
#  'cardiac',
#  'catheterization',
#  'showing',
#  'normal',
#  'coronaries',
#  'tumor',
#  'blush',
#  '.',
#  'follow',
#  '-',
#  'up',
#  'coronary',
#  'angiography',
#  'fluoroscopy',
#  'showed',
#  'gap',
#  'stent',
#  'strut',
#  '.',
#  'a',
#  '-',
#  'd',
#  ':',
#  'gap',
#  'stent',
#  'strut',
#  '.',
#  'right',
#  '-',
#  'sided',
#  'metatarsal',
#  'dorsoplantar',
#  'projection',
#  '.',
#  'cow',
#  '.',
#  'age',
#  'group',
#  'iv',
#  '—',
#  'cattle',
#  '4',
#  '–',
#  '8',
#  'years',
#  '.',
#  '(',
#  'a',
#  ')',
#  'narrow',
#  'symphysis',
#  '(',
#  'b',
#  ')',
#  'indistinct',
#  'bone',
#  'surface',
#  '.',
#  'fourth',
#  'patient',
#  '’',
#  's',
#  'mri',
#  'orthopantomograph',
#  'focal',
#  'steatosis',
#  'liver',
#  'parenchyma',
#  'preoperative',
#  'tte',
#  ',',
#  'end',
#  'diastole',
#  '(',
#  'preop',
#  'pics',
#  ').',
#  'magnetic',
#  'resonance',
#  't2',
#  'weighted',
#  'image',
#  'showing',
#  'foraminal',
#  'extensions',
#  'cysts',
#  'post',
#  '-',
#  'treatment',
#  'mriaxial',
#  't1',
#  '-',
#  'weighted',
#  ',',
#  'contrast',
#  '-',
#  'enhanced',
#  'image',
#  'showing',
#  'lesion',
#  'figure',
#  '3',
#  '.',
#  'abdominal',
#  'ct',
#  'scan',
#  'showing',
#  'pancreatic',
#  'pseudocyst',
#  'axial',
#  'contrast',
#  '-',
#  'enhanced',
#  'computed',
#  'tomography',
#  'image',
#  'abdomen',
#  '3',
#  'months',
#  'anti',
#  'tuberculous',
#  'treatment',
#  'showing',
#  'complete',
#  'resolution',
#  'lesions',
#  'lytic',
#  'lesions',
#  '(',
#  'arrows',
#  ')',
#  'involving',
#  'humerus',
#  '.',
#  'fluoroscopy',
#  'image',
#  'evar',
#  'procedure',
#  '.',
#  'ap',
#  'pelvis',
#  'x',
#  '-',
#  'ray',
#  'obtained',
#  '6',
#  'weeks',
#  'initial',
#  'presentation',
#  'shows',
#  'early',
#  'femoral',
#  'head',
#  'collapse',
#  '.',
#  'postoperative',
#  'control',
#  'following',
#  'periapical',
#  'surgery',
#  '.',
#  'ct',
#  'image',
#  'liver',
#  'shows',
#  'air',
#  'hepatic',
#  'veins',
#  '(',
#  'arrow',
#  ')',
#  'air',
#  '-',
#  'contrast',
#  'level',
#  'inferior',
#  'vena',
#  'cava',
#  '(',
#  'arrowhead',
#  ').',
#  'sfa',
#  'perforated',
#  'glidewire',
#  'insertion',
#  'attempt',
#  'cross',
#  'lesion',
#  '.',
#  'postoperative',
#  'computed',
#  'tomography',
#  'scan',
#  '18',
#  '-',
#  'year',
#  '-',
#  'old',
#  'woman',
#  'venous',
#  'tumor',
#  'thrombus',
#  '.',
#  'axial',
#  't1w',
#  'fat',
#  '-',
#  'saturated',
#  ',',
#  'postcontrast',
#  'mr',
#  'image',
#  'pelvis',
#  '.',
#  'x',
#  '-',
#  'ray',
#  'control',
#  'calcaneus',
#  'drilling',
#  'transvaginal',
#  'image',
#  'maternal',
#  'pelvis',
#  'demonstrating',
#  'cervical',
#  'length',
#  '.',
#  'probe',
#  'first',
#  'advanced',
#  'anterior',
#  'fornix',
#  'slightly',
#  'withdrawn',
#  'good',
#  'image',
#  'quality',
#  'maintained',
#  'avoiding',
#  'placing',
#  'pressure',
#  'cervix',
#  '.',
#  'cervical',
#  'length',
#  'measured',
#  'internal',
#  'external',
#  'os',
#  '.',
#  'endocervical',
#  'canal',
#  'also',
#  'marked',
#  'differentiated',
#  'echolucency',
#  '.',
#  'anterior',
#  'posterior',
#  'cervical',
#  'walls',
#  'similar',
#  'thickness',
#  '.',
#  'opg',
#  'showing',
#  'well',
#  'defined',
#  'corticated',
#  'radiolucency',
#  'containing',
#  'two',
#  'supernumerary',
#  'premolars',
#  'computed',
#  'tomography',
#  'scan',
#  'obtained',
#  'december',
#  '24',
#  ',',
#  '2014',
#  '(',
#  '7',
#  'days',
#  'treatment',
#  ').',
#  'notes',
#  ':',
#  'scan',
#  'demonstrates',
#  'mass',
#  'upper',
#  'lobe',
#  'left',
#  'lung',
#  ',',
#  'multiple',
#  'enlarged',
#  'lymph',
#  'nodes',
#  'mediastinum',
#  ',',
#  'pleural',
#  'effusion',
#  ';',
#  'arrow',
#  'indicates',
#  'abundant',
#  'pericardial',
#  'effusion',
#  'around',
#  'pericardium',
#  '.',
#  'coronal',
#  'contrast',
#  'chest',
#  'ct',
#  'image',
#  'showing',
#  'two',
#  'aberrant',
#  'arteries',
#  '(',
#  'white',
#  'arrow',
#  ')',
#  'arising',
#  'directly',
#  'thoracic',
#  'aorta',
#  'left',
#  'lower',
#  'lobe',
#  'cystic',
#  'lesion',
#  '.',
#  'osteoid',
#  'osteoma',
#  'femur',
#  '.',
#  'axial',
#  'ct',
#  'scan',
#  'shows',
#  'nidus',
#  '(',
#  'arrow',
#  ')',
#  'within',
#  'cortex',
#  ',',
#  'surrounding',
#  'dense',
#  'sclerosis',
#  '(',
#  'arrowhead',
#  ')',
#  'mandibular',
#  'occlusal',
#  'view',
#  'radiograph',
#  'showing',
#  'fusion',
#  'mandibular',
#  'teeth',
#  'talon',
#  'cusp',
#  'respect',
#  '41',
#  '42',
#  'intraoperative',
#  't2w',
#  'mr',
#  'image',
#  'showing']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(text_input)
# Out:
# ['computed',
#  'tomography',
#  'scan',
#  'axial',
#  'view',
#  'showing',
#  'obliteration',
#  'left',
#  'maxillary',
#  'sinus',
#  'bacterial',
#  'contamination',
#  'occurred',
#  'completion',
#  'root',
#  'canal',
#  'treatment',
#  'tooth',
#  ',',
#  'remained',
#  'temporary',
#  'filling',
#  '15',
#  'month.',
#  'patient',
#  'residual',
#  'paralysis',
#  'hand',
#  'poliomyelitis.',
#  'necessary',
#  'stabilize',
#  'thumb',
#  'reference',
#  'index',
#  'finger.',
#  'accomplished',
#  'placing',
#  'graft',
#  'bone',
#  'bank',
#  'first',
#  'second',
#  'metacarpals.',
#  'roentgenogram',
#  'shows',
#  'complete',
#  'healing',
#  'graft',
#  'one',
#  'year',
#  'later.',
#  'panoramic',
#  'radiograph',
#  'immediate',
#  'loading.',
#  'plain',
#  'abdomen',
#  'x-ray',
#  ':',
#  'multiple',
#  'air',
#  'levels',
#  'mid-abdomen',
#  '(',
#  'arrows',
#  ')',
#  ',',
#  'radiopaque',
#  'shadow',
#  ',',
#  'air',
#  'diaphragm.',
#  '3-year-old',
#  'child',
#  'visual',
#  'difficulties.',
#  'axial',
#  'flair',
#  'image',
#  'show',
#  'supra-sellar',
#  'lesion',
#  'extending',
#  'temporal',
#  'lobes',
#  'along',
#  'optic',
#  'tracts',
#  '(',
#  'arrows',
#  ')',
#  'moderate',
#  'mass',
#  'effect',
#  ',',
#  'compatible',
#  'optic',
#  'glioma.',
#  'flair',
#  'hyperintensity',
#  'also',
#  'noted',
#  'left',
#  'mesencephalon',
#  'additional',
#  'tumoral',
#  'involvement',
#  'showing',
#  'subtrochanteric',
#  'fracture',
#  'porotic',
#  'bone.',
#  'post',
#  'orthodontic',
#  'treatment.',
#  'root',
#  'canal',
#  'therapy',
#  'done',
#  'maxillary',
#  'incisors',
#  'two',
#  'sequential',
#  'thrombi',
#  'distal',
#  'segment',
#  'obtuse',
#  'marginal',
#  '2',
#  '(',
#  'om2',
#  ')',
#  '.',
#  'example',
#  'mri',
#  'image',
#  'takes',
#  'advantage',
#  'joint',
#  'effusion',
#  'contrast',
#  'material',
#  'acute',
#  'scenario.',
#  '57x46mm',
#  '(',
#  '150',
#  'x',
#  '150',
#  'dpi',
#  ')',
#  '.',
#  'child',
#  'abduction',
#  'flexion',
#  'right',
#  'lower',
#  'extremity',
#  'hyperextension',
#  'tibia',
#  'femur',
#  ',',
#  'associated',
#  'dislocation',
#  'left',
#  'hip',
#  ',',
#  'probably',
#  'result',
#  'dangerous',
#  'position',
#  'adduction',
#  'production',
#  'pathological',
#  'dislocation.',
#  'roentgenogram',
#  'mother’s',
#  'pelvis',
#  ',',
#  'one',
#  'week',
#  'delivery',
#  ',',
#  'showed',
#  'deformity',
#  'utero.',
#  'axial',
#  't2',
#  'haste',
#  'mr',
#  'image',
#  'shows',
#  'loss',
#  'normal',
#  'trilaminar',
#  'myometrial',
#  'architecture',
#  'mild',
#  'focal',
#  'thinning',
#  'placenta',
#  'site',
#  'compression',
#  'myometrium',
#  'front',
#  'aorta',
#  '(',
#  'black',
#  'arrow',
#  ')',
#  ',',
#  'proximal',
#  'bifurcation.',
#  'normal',
#  'trilaminar',
#  'signal',
#  'pattern',
#  'myometrium',
#  'seen',
#  'regions',
#  '(',
#  'white',
#  'arrows',
#  ')',
#  'hydronephrosis',
#  'appearance',
#  'sonography.',
#  'coronary',
#  'angiogram',
#  'demonstrating',
#  'occluded',
#  'om1',
#  'om2',
#  'arteries.',
#  'cardiac',
#  'catheterization',
#  'showing',
#  'normal',
#  'coronaries',
#  'tumor',
#  'blush.',
#  'follow-up',
#  'coronary',
#  'angiography',
#  'fluoroscopy',
#  'showed',
#  'gap',
#  'stent',
#  'strut.',
#  'a-d',
#  ':',
#  'gap',
#  'stent',
#  'strut.',
#  'right-sided',
#  'metatarsal',
#  'dorsoplantar',
#  'projection.cow.',
#  'age',
#  'group',
#  'iv—cattle',
#  '4–8',
#  'years.',
#  '(',
#  'a',
#  ')',
#  'narrow',
#  'symphysis',
#  '(',
#  'b',
#  ')',
#  'indistinct',
#  'bone',
#  'surface.',
#  'fourth',
#  'patient’s',
#  'mri',
#  'orthopantomograph',
#  'focal',
#  'steatosis',
#  'liver',
#  'parenchyma',
#  'preoperative',
#  'tte',
#  ',',
#  'end',
#  'diastole',
#  '(',
#  'preop',
#  'pics',
#  ')',
#  '.',
#  'magnetic',
#  'resonance',
#  't2',
#  'weighted',
#  'image',
#  'showing',
#  'foraminal',
#  'extensions',
#  'cysts',
#  'post-treatment',
#  'mriaxial',
#  't1-weighted',
#  ',',
#  'contrast-enhanced',
#  'image',
#  'showing',
#  'lesion',
#  'figure',
#  '3.',
#  'abdominal',
#  'ct',
#  'scan',
#  'showing',
#  'pancreatic',
#  'pseudocyst',
#  'axial',
#  'contrast-enhanced',
#  'computed',
#  'tomography',
#  'image',
#  'abdomen',
#  '3',
#  'months',
#  'anti',
#  'tuberculous',
#  'treatment',
#  'showing',
#  'complete',
#  'resolution',
#  'lesions',
#  'lytic',
#  'lesions',
#  '(',
#  'arrows',
#  ')',
#  'involving',
#  'humerus.',
#  'fluoroscopy',
#  'image',
#  'evar',
#  'procedure.',
#  'ap',
#  'pelvis',
#  'x-ray',
#  'obtained',
#  '6',
#  'weeks',
#  'initial',
#  'presentation',
#  'shows',
#  'early',
#  'femoral',
#  'head',
#  'collapse.',
#  'postoperative',
#  'control',
#  'following',
#  'periapical',
#  'surgery.',
#  'ct',
#  'image',
#  'liver',
#  'shows',
#  'air',
#  'hepatic',
#  'veins',
#  '(',
#  'arrow',
#  ')',
#  'air-contrast',
#  'level',
#  'inferior',
#  'vena',
#  'cava',
#  '(',
#  'arrowhead',
#  ')',
#  '.',
#  'sfa',
#  'perforated',
#  'glidewire',
#  'insertion',
#  'attempt',
#  'cross',
#  'lesion.',
#  'postoperative',
#  'computed',
#  'tomography',
#  'scan',
#  '18-year-old',
#  'woman',
#  'venous',
#  'tumor',
#  'thrombus.',
#  'axial',
#  't1w',
#  'fat-saturated',
#  ',',
#  'postcontrast',
#  'mr',
#  'image',
#  'pelvis.',
#  'x-ray',
#  'control',
#  'calcaneus',
#  'drilling',
#  'transvaginal',
#  'image',
#  'maternal',
#  'pelvis',
#  'demonstrating',
#  'cervical',
#  'length.',
#  'probe',
#  'first',
#  'advanced',
#  'anterior',
#  'fornix',
#  'slightly',
#  'withdrawn',
#  'good',
#  'image',
#  'quality',
#  'maintained',
#  'avoiding',
#  'placing',
#  'pressure',
#  'cervix.',
#  'cervical',
#  'length',
#  'measured',
#  'internal',
#  'external',
#  'os.',
#  'endocervical',
#  'canal',
#  'also',
#  'marked',
#  'differentiated',
#  'echolucency.',
#  'anterior',
#  'posterior',
#  'cervical',
#  'walls',
#  'similar',
#  'thickness.',
#  'opg',
#  'showing',
#  'well',
#  'defined',
#  'corticated',
#  'radiolucency',
#  'containing',
#  'two',
#  'supernumerary',
#  'premolars',
#  'computed',
#  'tomography',
#  'scan',
#  'obtained',
#  'december',
#  '24',
#  ',',
#  '2014',
#  '(',
#  '7',
#  'days',
#  'treatment',
#  ')',
#  '.notes',
#  ':',
#  'scan',
#  'demonstrates',
#  'mass',
#  'upper',
#  'lobe',
#  'left',
#  'lung',
#  ',',
#  'multiple',
#  'enlarged',
#  'lymph',
#  'nodes',
#  'mediastinum',
#  ',',
#  'pleural',
#  'effusion',
#  ';',
#  'arrow',
#  'indicates',
#  'abundant',
#  'pericardial',
#  'effusion',
#  'around',
#  'pericardium.',
#  'coronal',
#  'contrast',
#  'chest',
#  'ct',
#  'image',
#  'showing',
#  'two',
#  'aberrant',
#  'arteries',
#  '(',
#  'white',
#  'arrow',
#  ')',
#  'arising',
#  'directly',
#  'thoracic',
#  'aorta',
#  'left',
#  'lower',
#  'lobe',
#  'cystic',
#  'lesion.',
#  'osteoid',
#  'osteoma',
#  'femur.',
#  'axial',
#  'ct',
#  'scan',
#  'shows',
#  'nidus',
#  '(',
#  'arrow',
#  ')',
#  'within',
#  'cortex',
#  ',',
#  'surrounding',
#  'dense',
#  'sclerosis',
#  '(',
#  'arrowhead',
#  ')',
#  'mandibular',
#  'occlusal',
#  'view',
#  'radiograph',
#  'showing',
#  'fusion',
#  'mandibular',
#  'teeth',
#  'talon',
#  'cusp',
#  'respect',
#  '41',
#  '42',
#  'intraoperative',
#  't2w',
#  'mr',
#  'image',
#  'showing']

# %% [markdown]
# ### STEMMING

# %%
words=["eating","eats","eaten","writing","writes","programming"]

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
  print(word+"---"+stemming.stem(word))
# Out:
# eating---eat
# eats---eat
# eaten---eaten
# writing---write
# writes---write
# programming---program

# %%
stemming.stem("congratulations")
# Out:
# 'congratul'

# %% [markdown]
# ### REGEX STEMMER

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer("ing$|e$|s$|able$")

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("trains")
# Out:
# 'train'

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'ingeat'

# %% [markdown]
# ## SnowBallStemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer=SnowballStemmer('english')

# %%
for word in words:
  print(word+"---"+snowballstemmer.stem(word))
# Out:
# eating---eat
# eats---eat
# eaten---eaten
# writing---write
# writes---write
# programming---program

# %%
stemming.stem("sportingly"),snowballstemmer.stem("sportingly")
# Out:
# ('sportingli', 'sport')

# %%
### LEMMATIZATION

# %%
from nltk.stem import WordNetLemmatizer
import nltk

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer=WordNetLemmatizer()

# %%
'''
Noun-n
verb-v
adjective-a
adverb-r
'''
# Out:
# '\nNoun-n\nverb-v\nadjective-a\nadverb-r\n'

# %%
lemmatizer.lemmatize("corpora",pos="n")
# Out:
# 'corpus'
